# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/ML fundamentals/Naive Bayes
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/ML fundamentals/Naive Bayes

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import numpy as np
from NaiveBayes import NaiveBayes
from dotenv import load_dotenv
import os

# %%
load_dotenv('/content/drive/MyDrive/Colab Notebooks/ML fundamentals/.env')

# Access the token
token = os.getenv('GITHUB_TOKEN')

# %%
# !cd "/content/drive/MyDrive/Colab Notebooks/ML fundamentals" && git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/ML fundamentals/.git/

# %%
# !cd "/content/drive/MyDrive/Colab Notebooks/ML fundamentals" && git remote add origin https://github.com/marryabd/Fundamental-ML.git

# %%
# Pull the latest changes from the remote repository
# !cd "/content/drive/MyDrive/Colab Notebooks/ML fundamentals" && git pull origin main
# Out:
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 12 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (12/12), 3.88 KiB | 2.00 KiB/s, done.
# From https://github.com/marryabd/Fundamental-ML
#  * branch            main       -> FETCH_HEAD
#    8b6dd51..3a91d23  main       -> origin/main
# Updating 8b6dd51..3a91d23
# Fast-forward
#  Decision Tree/__pycache__/DecisionTree.cpython-310.pyc | Bin 4668 -> 0 bytes
#  KNN/__pycache__/knn_model.cpython-310.pyc              | Bin 1679 -> 0 bytes
#  Logistic Reg/__pycache__/LogisticReg.cpython-310.pyc   | Bin 1585 -> 0 bytes
#  Random Forest/__pycache__/DecisionTree.cpython-310.pyc | Bin 4775 -> 0 bytes
#  Random Forest/__pycache__/RandomForest.cpython-310.pyc | Bin 2040 -> 0 bytes
#  5 files changed, 0 insertions(+), 0 deletions(-)
#  delete mode 100644 Decision Tree/__pycache__/DecisionTree.cpython-310.pyc
#  delete mode 100644 KNN/__pycache__/knn_model.cpython-310.pyc
#  delete mode 100644 Logistic Reg/__pycache__/LogisticReg.cpython-310.pyc
#  delete mode 100644 Random Forest/__pycache__/DecisionTree.cpython-310.pyc
#  delete mode 100644 Random Forest/__pycache__/RandomForest.cpython-310.pyc

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets

def accuracy(y_true, y_pred):
    accuracy = np.sum(y_true == y_pred) / len(y_true)
    return accuracy

X, y = datasets.make_classification(
    n_samples=1000, n_features=10, n_classes=2, random_state=123
)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=123
)

# %%
X_train[y_train == 1].mean(axis=0)
# Out:
# array([-0.01370928,  0.0759941 ,  0.23715563,  0.19411855, -0.04140421,
#         0.0344645 , -0.05965791, -0.1024946 ,  1.03415648,  0.05188555])

# %%
# Out:
# array([[-0.63950524, -0.23584751, -0.28840218, ..., -0.68415371,
#          1.18943464, -0.31669551],
#        [ 0.66938907,  0.58792246, -0.81990885, ..., -1.77640152,
#         -1.09832947, -0.76501501],
#        [ 0.72025002,  1.47831033, -1.28082896, ...,  1.68993071,
#         -1.83623101,  0.11659189],
#        ...,
#        [ 0.25580835,  0.82552227, -0.52106521, ...,  1.25136485,
#         -0.65704429, -1.06897562],
#        [-0.25784178,  0.74700984,  0.49867336, ..., -0.42663516,
#          2.36320034, -1.91958189],
#        [-0.44085998,  0.87432692,  0.34667373, ...,  0.18247735,
#          1.98240441, -0.57978104]])

# %%
# !cd "/content/drive/MyDrive/Colab Notebooks/ML fundamentals" && git add .

# %%
# !git config user.email "mariam.abdollahi@gmail.com"
# !git config  user.name "marryabd"

# %%
# !cd "/content/drive/MyDrive/Colab Notebooks/ML fundamentals" && git commit -m "Sync from Google Drive"
# Out:
# [main 8b6dd51] Sync from Google Drive
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Random Forest/run.ipynb (92%)

# %%
# !cd "/content/drive/MyDrive/Colab Notebooks/ML fundamentals" && git remote set-url origin https://marryabd:{token}@github.com/marryabd/Fundamental-ML.git

# %%
# !cd "/content/drive/MyDrive/Colab Notebooks/ML fundamentals" && git push origin main
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.63 KiB | 98.00 KiB/s, done.
# Total 4 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/marryabd/Fundamental-ML.git
#    48cb332..8b6dd51  main -> main

# %%
class subject():
  count = 0
  def __init__(self):
      self.__name = 'name'

# %%
I = subject()

# %%
I.show_info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-be5cdc107109> in <cell line: 1>()
# ----> 1 I.show_info()
#
# AttributeError: 'subject' object has no attribute 'show_info'
